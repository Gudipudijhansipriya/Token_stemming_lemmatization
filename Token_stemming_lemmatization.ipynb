# %% [markdown]
# #### Tokenization

# %%
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# * Tokenization is the process of replacing sensitive data with unique identification symbols that retain all the essential information about the data without compromising its security.

# %%
para="A screenwriter writes a script, which is the story of the movie with dialogue and things that the actors will say and do. A producer hires people to work on the movie and gets all of the money that will be needed to pay for the actors and the equipment. Producers usually get the money by borrowing it from a bank or by getting investors to lend money to the movie production. Some producers work for a movie studio; other producers are independent (they do not work for a movie studio).Actors and directors read scripts to find out what to say and what to do. The actors memorize the words from the script that they will say in the movie, and learn the actions that the script tells them to do. Then, the director tells the actors what to do and a cameraman takes motion pictures of them with a motion picture camera.When filming has finished, an editor puts the moving pictures together in a way that tells the whole story within a set amount of time. Audio engineers and sound engineers record music and singing and join it with the moving pictures. When the movie is done, many copies of the movie are made by movie labs and put onto film reels. Then the reels are sent to cinemas. An electric machine called a projector shines a very bright light through the film, and people sitting in a dark room see it on a big screen."
nltk_tokens=nltk.word_tokenize(para)
print(nltk_tokens,end=" ")
# Out:
# ['A', 'screenwriter', 'writes', 'a', 'script', ',', 'which', 'is', 'the', 'story', 'of', 'the', 'movie', 'with', 'dialogue', 'and', 'things', 'that', 'the', 'actors', 'will', 'say', 'and', 'do', '.', 'A', 'producer', 'hires', 'people', 'to', 'work', 'on', 'the', 'movie', 'and', 'gets', 'all', 'of', 'the', 'money', 'that', 'will', 'be', 'needed', 'to', 'pay', 'for', 'the', 'actors', 'and', 'the', 'equipment', '.', 'Producers', 'usually', 'get', 'the', 'money', 'by', 'borrowing', 'it', 'from', 'a', 'bank', 'or', 'by', 'getting', 'investors', 'to', 'lend', 'money', 'to', 'the', 'movie', 'production', '.', 'Some', 'producers', 'work', 'for', 'a', 'movie', 'studio', ';', 'other', 'producers', 'are', 'independent', '(', 'they', 'do', 'not', 'work', 'for', 'a', 'movie', 'studio', ')', '.Actors', 'and', 'directors', 'read', 'scripts', 'to', 'find', 'out', 'what', 'to', 'say', 'and', 'what', 'to', 'do', '.', 'The', 'actors', 'memorize', 'the', 'words', 'from', 'the', 'script', 'that', 'they', 'will', 'say', 'in', 'the', 'movie', ',', 'and', 'learn', 'the', 'actions', 'that', 'the', 'script', 'tells', 'them', 'to', 'do', '.', 'Then', ',', 'the', 'director', 'tells', 'the', 'actors', 'what', 'to', 'do', 'and', 'a', 'cameraman', 'takes', 'motion', 'pictures', 'of', 'them', 'with', 'a', 'motion', 'picture', 'camera.When', 'filming', 'has', 'finished', ',', 'an', 'editor', 'puts', 'the', 'moving', 'pictures', 'together', 'in', 'a', 'way', 'that', 'tells', 'the', 'whole', 'story', 'within', 'a', 'set', 'amount', 'of', 'time', '.', 'Audio', 'engineers', 'and', 'sound', 'engineers', 'record', 'music', 'and', 'singing', 'and', 'join', 'it', 'with', 'the', 'moving', 'pictures', '.', 'When', 'the', 'movie', 'is', 'done', ',', 'many', 'copies', 'of', 'the', 'movie', 'are', 'made', 'by', 'movie', 'labs', 'and', 'put', 'onto', 'film', 'reels', '.', 'Then', 'the', 'reels', 'are', 'sent', 'to', 'cinemas', '.', 'An', 'electric', 'machine', 'called', 'a', 'projector', 'shines', 'a', 'very', 'bright', 'light', 'through', 'the', 'film', ',', 'and', 'people', 'sitting', 'in', 'a', 'dark', 'room', 'see', 'it', 'on', 'a', 'big', 'screen', '.']

# %% [markdown]
# #### Stemming

# %% [markdown]
# * Stemming is a method of normalization of words in Natural Language Processing. It is a technique in which a set of words in a sentence are converted into a sequence to shorten its lookup. In this method, the words having the same meaning but have some variations according to the context or sentence are normalized.
#
#
# * In another word, there is one root word, but there are many variations of the same words.
#
#
# * Let’s first understand stemming:
#
#     * Stemming is a text normalization technique that cuts off the end or beginning of a word by taking into account a       list of common prefixes or suffixes that could be found in that word
#     * It is a rudimentary rule-based process of stripping the suffixes (“ing”, “ly”, “es”, “s” etc) from a word

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
porter=PorterStemmer()
lancaster=LancasterStemmer()

# %%
list1=['A', 'screenwriter', 'writes', 'a', 'script', ',', 'which', 'is', 'the', 'story', 'of', 'the', 'movie', 'with', 'dialogue', 'and', 'things', 'that', 'the', 'actors', 'will', 'say', 'and', 'do', '.', 'A', 'producer', 'hires', 'people', 'to', 'work', 'on', 'the', 'movie', 'and', 'gets', 'all', 'of', 'the', 'money', 'that', 'will', 'be', 'needed', 'to', 'pay', 'for', 'the', 'actors', 'and', 'the', 'equipment', '.', 'Producers', 'usually', 'get', 'the', 'money', 'by', 'borrowing', 'it', 'from', 'a', 'bank', 'or', 'by', 'getting', 'investors', 'to', 'lend', 'money', 'to', 'the', 'movie', 'production', '.', 'Some', 'producers', 'work', 'for', 'a', 'movie', 'studio', ';', 'other', 'producers', 'are', 'independent', '(', 'they', 'do', 'not', 'work', 'for', 'a', 'movie', 'studio', ')', '.Actors', 'and', 'directors', 'read', 'scripts', 'to', 'find', 'out', 'what', 'to', 'say', 'and', 'what', 'to', 'do', '.', 'The', 'actors', 'memorize', 'the', 'words', 'from', 'the', 'script', 'that', 'they', 'will', 'say', 'in', 'the', 'movie', ',', 'and', 'learn', 'the', 'actions', 'that', 'the', 'script', 'tells', 'them', 'to', 'do', '.', 'Then', ',', 'the', 'director', 'tells', 'the', 'actors', 'what', 'to', 'do', 'and', 'a', 'cameraman', 'takes', 'motion', 'pictures', 'of', 'them', 'with', 'a', 'motion', 'picture', 'camera.When', 'filming', 'has', 'finished', ',', 'an', 'editor', 'puts', 'the', 'moving', 'pictures', 'together', 'in', 'a', 'way', 'that', 'tells', 'the', 'whole', 'story', 'within', 'a', 'set', 'amount', 'of', 'time', '.', 'Audio', 'engineers', 'and', 'sound', 'engineers', 'record', 'music', 'and', 'singing', 'and', 'join', 'it', 'with', 'the', 'moving', 'pictures', '.', 'When', 'the', 'movie', 'is', 'done', ',', 'many', 'copies', 'of', 'the', 'movie', 'are', 'made', 'by', 'movie', 'labs', 'and', 'put', 'onto', 'film', 'reels', '.', 'Then', 'the', 'reels', 'are', 'sent', 'to', 'cinemas', '.', 'An', 'electric', 'machine', 'called', 'a', 'projector', 'shines', 'a', 'very', 'bright', 'light', 'through', 'the', 'film', ',', 'and', 'people', 'sitting', 'in', 'a', 'dark', 'room', 'see', 'it', 'on', 'a', 'big', 'screen', '.'] 
print("{0:20}{1:20}{2:20}".format("word","porter Stemmer","lancaster Stemmer"))
for word in list1:
    print("{0:20}{1:20}{2:20}".format(word,porter.stem(word),lancaster.stem(word)))
# Out:
# word                porter Stemmer      lancaster Stemmer
# A                   a                   a
# screenwriter        screenwrit          screenwriter
# writes              write               writ
# a                   a                   a
# script              script              script
# ,                   ,                   ,
# which               which               which
# is                  is                  is
# the                 the                 the
# story               stori               story
# of                  of                  of
# the                 the                 the
# movie               movi                movy
# with                with                with
# dialogue            dialogu             dialog
# and                 and                 and
# things              thing               thing
# that                that                that
# the                 the                 the
# actors              actor               act
# will                will                wil
# say                 say                 say
# and                 and                 and
# do                  do                  do
# .                   .                   .
# A                   a                   a
# producer            produc              produc
# hires               hire                hir
# people              peopl               peopl
# to                  to                  to
# work                work                work
# on                  on                  on
# the                 the                 the
# movie               movi                movy
# and                 and                 and
# gets                get                 get
# all                 all                 al
# of                  of                  of
# the                 the                 the
# money               money               money
# that                that                that
# will                will                wil
# be                  be                  be
# needed              need                nee
# to                  to                  to
# pay                 pay                 pay
# for                 for                 for
# the                 the                 the
# actors              actor               act
# and                 and                 and
# the                 the                 the
# equipment           equip               equip
# .                   .                   .
# Producers           produc              produc
# usually             usual               us
# get                 get                 get
# the                 the                 the
# money               money               money
# by                  by                  by
# borrowing           borrow              borrow
# it                  it                  it
# from                from                from
# a                   a                   a
# bank                bank                bank
# or                  or                  or
# by                  by                  by
# getting             get                 get
# investors           investor            invest
# to                  to                  to
# lend                lend                lend
# money               money               money
# to                  to                  to
# the                 the                 the
# movie               movi                movy
# production          product             produc
# .                   .                   .
# Some                some                som
# producers           produc              produc
# work                work                work
# for                 for                 for
# a                   a                   a
# movie               movi                movy
# studio              studio              studio
# ;                   ;                   ;
# other               other               oth
# producers           produc              produc
# are                 are                 ar
# independent         independ            independ
# (                   (                   (
# they                they                they
# do                  do                  do
# not                 not                 not
# work                work                work
# for                 for                 for
# a                   a                   a
# movie               movi                movy
# studio              studio              studio
# )                   )                   )
# .Actors             .actor              .actors
# and                 and                 and
# directors           director            direct
# read                read                read
# scripts             script              scripts
# to                  to                  to
# find                find                find
# out                 out                 out
# what                what                what
# to                  to                  to
# say                 say                 say
# and                 and                 and
# what                what                what
# to                  to                  to
# do                  do                  do
# .                   .                   .
# The                 the                 the
# actors              actor               act
# memorize            memor               mem
# the                 the                 the
# words               word                word
# from                from                from
# the                 the                 the
# script              script              script
# that                that                that
# they                they                they
# will                will                wil
# say                 say                 say
# in                  in                  in
# the                 the                 the
# movie               movi                movy
# ,                   ,                   ,
# and                 and                 and
# learn               learn               learn
# the                 the                 the
# actions             action              act
# that                that                that
# the                 the                 the
# script              script              script
# tells               tell                tel
# them                them                them
# to                  to                  to
# do                  do                  do
# .                   .                   .
# Then                then                then
# ,                   ,                   ,
# the                 the                 the
# director            director            direct
# tells               tell                tel
# the                 the                 the
# actors              actor               act
# what                what                what
# to                  to                  to
# do                  do                  do
# and                 and                 and
# a                   a                   a
# cameraman           cameraman           cameram
# takes               take                tak
# motion              motion              mot
# pictures            pictur              pict
# of                  of                  of
# them                them                them
# with                with                with
# a                   a                   a
# motion              motion              mot
# picture             pictur              pict
# camera.When         camera.when         camera.when
# filming             film                film
# has                 ha                  has
# finished            finish              fin
# ,                   ,                   ,
# an                  an                  an
# editor              editor              edit
# puts                put                 put
# the                 the                 the
# moving              move                mov
# pictures            pictur              pict
# together            togeth              togeth
# in                  in                  in
# a                   a                   a
# way                 way                 way
# that                that                that
# tells               tell                tel
# the                 the                 the
# whole               whole               whol
# story               stori               story
# within              within              within
# a                   a                   a
# set                 set                 set
# amount              amount              amount
# of                  of                  of
# time                time                tim
# .                   .                   .
# Audio               audio               audio
# engineers           engin               engin
# and                 and                 and
# sound               sound               sound
# engineers           engin               engin
# record              record              record
# music               music               mus
# and                 and                 and
# singing             sing                sing
# and                 and                 and
# join                join                join
# it                  it                  it
# with                with                with
# the                 the                 the
# moving              move                mov
# pictures            pictur              pict
# .                   .                   .
# When                when                when
# the                 the                 the
# movie               movi                movy
# is                  is                  is
# done                done                don
# ,                   ,                   ,
# many                mani                many
# copies              copi                cop
# of                  of                  of
# the                 the                 the
# movie               movi                movy
# are                 are                 ar
# made                made                mad
# by                  by                  by
# movie               movi                movy
# labs                lab                 lab
# and                 and                 and
# put                 put                 put
# onto                onto                onto
# film                film                film
# reels               reel                reel
# .                   .                   .
# Then                then                then
# the                 the                 the
# reels               reel                reel
# are                 are                 ar
# sent                sent                sent
# to                  to                  to
# cinemas             cinema              cinema
# .                   .                   .
# An                  an                  an
# electric            electr              elect
# machine             machin              machin
# called              call                cal
# a                   a                   a
# projector           projector           project
# shines              shine               shin
# a                   a                   a
# very                veri                very
# bright              bright              bright
# light               light               light
# through             through             through
# the                 the                 the
# film                film                film
# ,                   ,                   ,
# and                 and                 and
# people              peopl               peopl
# sitting             sit                 sit
# in                  in                  in
# a                   a                   a
# dark                dark                dark
# room                room                room
# see                 see                 see
# it                  it                  it
# on                  on                  on
# a                   a                   a
# big                 big                 big
# screen              screen              screen
# .                   .                   .

# %% [markdown]
# #### Lemmatization

# %% [markdown]
# * Lemmatization in NLTK is the algorithmic process of finding the lemma of a word depending on its meaning and context. Lemmatization usually refers to the morphological analysis of words, which aims to remove inflectional endings. It helps in returning the base or dictionary form of a word known as the lemma.
#
#
# * Lemmatization, on the other hand, is an organized & step-by-step procedure of obtaining the root form of the word. It makes use of vocabulary (dictionary importance of words) and morphological analysis (word structure and grammar relations).

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer=WordNetLemmatizer()
movie="A screenwriter writes a script, which is the story of the movie with dialogue and things that the actors will say and do. A producer hires people to work on the movie and gets all of the money that will be needed to pay for the actors and the equipment. Producers usually get the money by borrowing it from a bank or by getting investors to lend money to the movie production. Some producers work for a movie studio; other producers are independent (they do not work for a movie studio).Actors and directors read scripts to find out what to say and what to do. The actors memorize the words from the script that they will say in the movie, and learn the actions that the script tells them to do. Then, the director tells the actors what to do and a cameraman takes motion pictures of them with a motion picture camera.When filming has finished, an editor puts the moving pictures together in a way that tells the whole story within a set amount of time. Audio engineers and sound engineers record music and singing and join it with the moving pictures. When the movie is done, many copies of the movie are made by movie labs and put onto film reels. Then the reels are sent to cinemas. An electric machine called a projector shines a very bright light through the film, and people sitting in a dark room see it on a big screen."
tokenization=nltk.word_tokenize(movie)
for w in tokenization:
    print("Lemma is {} is {}".format(w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma is A is A
# Lemma is screenwriter is screenwriter
# Lemma is writes is writes
# Lemma is a is a
# Lemma is script is script
# Lemma is , is ,
# Lemma is which is which
# Lemma is is is is
# Lemma is the is the
# Lemma is story is story
# Lemma is of is of
# Lemma is the is the
# Lemma is movie is movie
# Lemma is with is with
# Lemma is dialogue is dialogue
# Lemma is and is and
# Lemma is things is thing
# Lemma is that is that
# Lemma is the is the
# Lemma is actors is actor
# Lemma is will is will
# Lemma is say is say
# Lemma is and is and
# Lemma is do is do
# Lemma is . is .
# Lemma is A is A
# Lemma is producer is producer
# Lemma is hires is hire
# Lemma is people is people
# Lemma is to is to
# Lemma is work is work
# Lemma is on is on
# Lemma is the is the
# Lemma is movie is movie
# Lemma is and is and
# Lemma is gets is get
# Lemma is all is all
# Lemma is of is of
# Lemma is the is the
# Lemma is money is money
# Lemma is that is that
# Lemma is will is will
# Lemma is be is be
# Lemma is needed is needed
# Lemma is to is to
# Lemma is pay is pay
# Lemma is for is for
# Lemma is the is the
# Lemma is actors is actor
# Lemma is and is and
# Lemma is the is the
# Lemma is equipment is equipment
# Lemma is . is .
# Lemma is Producers is Producers
# Lemma is usually is usually
# Lemma is get is get
# Lemma is the is the
# Lemma is money is money
# Lemma is by is by
# Lemma is borrowing is borrowing
# Lemma is it is it
# Lemma is from is from
# Lemma is a is a
# Lemma is bank is bank
# Lemma is or is or
# Lemma is by is by
# Lemma is getting is getting
# Lemma is investors is investor
# Lemma is to is to
# Lemma is lend is lend
# Lemma is money is money
# Lemma is to is to
# Lemma is the is the
# Lemma is movie is movie
# Lemma is production is production
# Lemma is . is .
# Lemma is Some is Some
# Lemma is producers is producer
# Lemma is work is work
# Lemma is for is for
# Lemma is a is a
# Lemma is movie is movie
# Lemma is studio is studio
# Lemma is ; is ;
# Lemma is other is other
# Lemma is producers is producer
# Lemma is are is are
# Lemma is independent is independent
# Lemma is ( is (
# Lemma is they is they
# Lemma is do is do
# Lemma is not is not
# Lemma is work is work
# Lemma is for is for
# Lemma is a is a
# Lemma is movie is movie
# Lemma is studio is studio
# Lemma is ) is )
# Lemma is .Actors is .Actors
# Lemma is and is and
# Lemma is directors is director
# Lemma is read is read
# Lemma is scripts is script
# Lemma is to is to
# Lemma is find is find
# Lemma is out is out
# Lemma is what is what
# Lemma is to is to
# Lemma is say is say
# Lemma is and is and
# Lemma is what is what
# Lemma is to is to
# Lemma is do is do
# Lemma is . is .
# Lemma is The is The
# Lemma is actors is actor
# Lemma is memorize is memorize
# Lemma is the is the
# Lemma is words is word
# Lemma is from is from
# Lemma is the is the
# Lemma is script is script
# Lemma is that is that
# Lemma is they is they
# Lemma is will is will
# Lemma is say is say
# Lemma is in is in
# Lemma is the is the
# Lemma is movie is movie
# Lemma is , is ,
# Lemma is and is and
# Lemma is learn is learn
# Lemma is the is the
# Lemma is actions is action
# Lemma is that is that
# Lemma is the is the
# Lemma is script is script
# Lemma is tells is tell
# Lemma is them is them
# Lemma is to is to
# Lemma is do is do
# Lemma is . is .
# Lemma is Then is Then
# Lemma is , is ,
# Lemma is the is the
# Lemma is director is director
# Lemma is tells is tell
# Lemma is the is the
# Lemma is actors is actor
# Lemma is what is what
# Lemma is to is to
# Lemma is do is do
# Lemma is and is and
# Lemma is a is a
# Lemma is cameraman is cameraman
# Lemma is takes is take
# Lemma is motion is motion
# Lemma is pictures is picture
# Lemma is of is of
# Lemma is them is them
# Lemma is with is with
# Lemma is a is a
# Lemma is motion is motion
# Lemma is picture is picture
# Lemma is camera.When is camera.When
# Lemma is filming is filming
# Lemma is has is ha
# Lemma is finished is finished
# Lemma is , is ,
# Lemma is an is an
# Lemma is editor is editor
# Lemma is puts is put
# Lemma is the is the
# Lemma is moving is moving
# Lemma is pictures is picture
# Lemma is together is together
# Lemma is in is in
# Lemma is a is a
# Lemma is way is way
# Lemma is that is that
# Lemma is tells is tell
# Lemma is the is the
# Lemma is whole is whole
# Lemma is story is story
# Lemma is within is within
# Lemma is a is a
# Lemma is set is set
# Lemma is amount is amount
# Lemma is of is of
# Lemma is time is time
# Lemma is . is .
# Lemma is Audio is Audio
# Lemma is engineers is engineer
# Lemma is and is and
# Lemma is sound is sound
# Lemma is engineers is engineer
# Lemma is record is record
# Lemma is music is music
# Lemma is and is and
# Lemma is singing is singing
# Lemma is and is and
# Lemma is join is join
# Lemma is it is it
# Lemma is with is with
# Lemma is the is the
# Lemma is moving is moving
# Lemma is pictures is picture
# Lemma is . is .
# Lemma is When is When
# Lemma is the is the
# Lemma is movie is movie
# Lemma is is is is
# Lemma is done is done
# Lemma is , is ,
# Lemma is many is many
# Lemma is copies is copy
# Lemma is of is of
# Lemma is the is the
# Lemma is movie is movie
# Lemma is are is are
# Lemma is made is made
# Lemma is by is by
# Lemma is movie is movie
# Lemma is labs is lab
# Lemma is and is and
# Lemma is put is put
# Lemma is onto is onto
# Lemma is film is film
# Lemma is reels is reel
# Lemma is . is .
# Lemma is Then is Then
# Lemma is the is the
# Lemma is reels is reel
# Lemma is are is are
# Lemma is sent is sent
# Lemma is to is to
# Lemma is cinemas is cinema
# Lemma is . is .
# Lemma is An is An
# Lemma is electric is electric
# Lemma is machine is machine
# Lemma is called is called
# Lemma is a is a
# Lemma is projector is projector
# Lemma is shines is shine
# Lemma is a is a
# Lemma is very is very
# Lemma is bright is bright
# Lemma is light is light
# Lemma is through is through
# Lemma is the is the
# Lemma is film is film
# Lemma is , is ,
# Lemma is and is and
# Lemma is people is people
# Lemma is sitting is sitting
# Lemma is in is in
# Lemma is a is a
# Lemma is dark is dark
# Lemma is room is room
# Lemma is see is see
# Lemma is it is it
# Lemma is on is on
# Lemma is a is a
# Lemma is big is big
# Lemma is screen is screen
# Lemma is . is .
